# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.1

# %%
url = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv"

# %%
df = pd.read_csv(url)

# %%
df.head(10)
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
# 5  MSI Crosshair 17 C12VF-264XES Intel Core i7-12...    New     MSI
# 6  Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8G...    New  Lenovo
# 7  ASUS VivoBook 15 F515JA-EJ2882W Intel Core i7-...    New    Asus
# 8  Medion Akoya E15415 Intel Core i5-10210U/8GB/2...    New  Medion
# 9  HP Victus 16-d1038ns Intel Core i7-12700H/16GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
# 5   Crosshair  Intel Core i7   32     1000          SSD  RTX 4060    17.3
# 6    ThinkPad    AMD Ryzen 5    8      256          SSD       NaN    14.0
# 7    VivoBook  Intel Core i7    8      512          SSD       NaN    15.6
# 8       Akoya  Intel Core i5    8      256          SSD       NaN    15.6
# 9      Victus  Intel Core i7   16      512          SSD  RTX 3050    16.1
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01
# 5    No      1699.00
# 6    No       909.00
# 7    No       809.01
# 8    No       519.00
# 9    No      1149.00

# %%
# !git add pandas.ipynb
# !git commit -m "pandas traininng"
# !git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.ipynb_checkpoints/
#
# nothing added to commit but untracked files present (use "git add" to track)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 2.54 KiB | 2.54 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# To https://github.com/georgesmbock/zoomcamp-ML-2025-home-work
#    a448a17..b89a66b  main -> main

# %%
# !pip install jupyterlab-drawio
# Out:
# Collecting jupyterlab-drawio
#   Downloading jupyterlab_drawio-0.9.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting jupyterlab==3.*,>=3.0.0rc13 (from jupyterlab-drawio)
#   Downloading jupyterlab-3.6.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: ipython in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (9.4.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (25.0)
# Requirement already satisfied: tornado>=6.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (6.5.1)
# Requirement already satisfied: jupyter-core in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (5.8.1)
# Requirement already satisfied: jupyterlab-server~=2.19 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.27.3)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.16.0)
# Collecting jupyter-ydoc~=0.2.4 (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading jupyter_ydoc-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting jupyter-server-ydoc~=0.8.0 (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading jupyter_server_ydoc-0.8.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting nbclassic (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading nbclassic-1.3.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting notebook<7 (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading notebook-6.5.7-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: jinja2>=2.1 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.1.6)
# Requirement already satisfied: anyio>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.22.1)
# Requirement already satisfied: pyzmq>=24 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (27.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.8.0)
# Collecting jupyter-server-fileid<1,>=0.6.0 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading jupyter_server_fileid-0.9.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting ypy-websocket<0.9.0,>=0.8.2 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading ypy_websocket-0.8.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting y-py<0.7.0,>=0.6.0 (from jupyter-ydoc~=0.2.4->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading y_py-0.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: babel>=2.10 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (4.24.0)
# Requirement already satisfied: requests>=2.31 in /home/codespace/.local/lib/python3.12/site-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.32.4)
# Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Collecting ipython-genutils (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.6.0)
# Requirement already satisfied: ipykernel in /home/codespace/.local/lib/python3.12/site-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (6.29.5)
# Collecting entrypoints (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.9.0.post0)
# Collecting aiofiles<23,>=22.1.0 (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading aiofiles-22.1.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting aiosqlite<1,>=0.17.0 (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiosqlite<1,>=0.17.0->ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/codespace/.local/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2>=2.1->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-core->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (4.3.8)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.1.1)
# Requirement already satisfied: fqdn in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.5.1)
# Requirement already satisfied: isoduration in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.0.0)
# Requirement already satisfied: uri-template in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (24.11.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /home/codespace/.local/lib/python3.12/site-packages (from nbclassic->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (6.2.0)
# Requirement already satisfied: defusedxml in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/codespace/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.19.2)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/codespace/.local/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.21.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2025.7.9)
# Requirement already satisfied: ptyprocess in /home/codespace/.local/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.17.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.7)
# Requirement already satisfied: comm>=0.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.8.14)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.1.7)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.12/site-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (7.0.0)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.12/site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/codespace/.local/lib/python3.12/site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.12/site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/codespace/.local/lib/python3.12/site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.0.51)
# Requirement already satisfied: stack_data in /home/codespace/.local/lib/python3.12/site-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.6.3)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/codespace/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.8.4)
# Requirement already satisfied: arrow>=0.15.0 in /home/codespace/.local/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/codespace/.local/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.9.0.20250708)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (3.0.0)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython->jupyterlab==3.*,>=3.0.0rc13->jupyterlab-drawio) (0.2.3)
# Downloading jupyterlab_drawio-0.9.0-py3-none-any.whl (795 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.2/795.2 kB 31.2 MB/s  0:00:00
# Downloading jupyterlab-3.6.8-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 64.4 MB/s  0:00:00
# Downloading jupyter_server_ydoc-0.8.0-py3-none-any.whl (11 kB)
# Downloading jupyter_server_fileid-0.9.3-py3-none-any.whl (16 kB)
# Downloading jupyter_ydoc-0.2.5-py3-none-any.whl (6.2 kB)
# Downloading notebook-6.5.7-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 35.3 MB/s  0:00:00
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
# Downloading y_py-0.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.2 MB/s  0:00:00
# Downloading ypy_websocket-0.8.4-py3-none-any.whl (10 kB)
# Downloading aiofiles-22.1.0-py3-none-any.whl (14 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading nbclassic-1.3.1-py3-none-any.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 80.4 MB/s  0:00:00s eta 0:00:01
# Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Installing collected packages: y-py, ipython-genutils, jupyter-ydoc, entrypoints, aiosqlite, aiofiles, ypy-websocket, jupyter-client, jupyter-server-fileid, nbclassic, jupyter-server-ydoc, notebook, jupyterlab, jupyterlab-drawio
#   Attempting uninstall: jupyter-client38;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/14 [aiosqlite]
#     Found existing installation: jupyter_client 8.6.35;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/14 [aiosqlite]
#     Uninstalling jupyter_client-8.6.3:;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/14 [aiosqlite]
#       Successfully uninstalled jupyter_client-8.6.38;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/14 [aiosqlite]
#   Attempting uninstall: notebook━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  9/14 [nbclassic]
#     Found existing installation: notebook 7.4.5╸━━━━━━━━━━━━━━  9/14 [nbclassic]
#     Uninstalling notebook-7.4.5:━━━━━━━━━━╸━━━━━━━━━━━━━━  9/14 [nbclassic]
#       Successfully uninstalled notebook-7.4.5m╸━━━━━━━━━━━━━━  9/14 [nbclassic]
#   Attempting uninstall: jupyterlab━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 11/14 [notebook]sic]
#     Found existing installation: jupyterlab 4.4.6╺━━━━━━━━ 11/14 [notebook]
#     Uninstalling jupyterlab-4.4.6:━━━━━━━━━━━━━━╺━━━━━━━━ 11/14 [notebook]
#       Successfully uninstalled jupyterlab-4.4.6━╺━━━━━━━━ 11/14 [notebook]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [jupyterlab-drawio]m12/14 [jupyterlab]
# Successfully installed aiofiles-22.1.0 aiosqlite-0.21.0 entrypoints-0.4 ipython-genutils-0.2.0 jupyter-client-7.4.9 jupyter-server-fileid-0.9.3 jupyter-server-ydoc-0.8.0 jupyter-ydoc-0.2.5 jupyterlab-3.6.8 jupyterlab-drawio-0.9.0 nbclassic-1.3.1 notebook-6.5.7 y-py-0.6.2 ypy-websocket-0.8.4
